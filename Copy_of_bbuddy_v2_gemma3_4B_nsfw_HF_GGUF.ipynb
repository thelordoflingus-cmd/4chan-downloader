# %% [markdown]
# <a href="https://colab.research.google.com/github/thelordoflingus-cmd/4chan-downloader/blob/master/Copy_of_bbuddy_v2_gemma3_4B_nsfw_HF_GGUF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U llama-cpp-python
# Out:
# ...
#   Using cached llama_cpp_python-0.3.16.tar.gz (50.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached diskcache-5.6.3-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached diskcache-5.6.3-py3-none-any.whl (45 kB)
# ...

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/mradermacher/bbuddy-v2-gemma3-4B-nsfw-HF-GGUF
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/mradermacher/bbuddy-v2-gemma3-4B-nsfw-HF-GGUF)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# !pip install llama-cpp-python

from llama_cpp import Llama

llm = Llama.from_pretrained(
    repo_id="mradermacher/bbuddy-v2-gemma3-4B-nsfw-HF-GGUF",
    filename="bbuddy-v2-gemma3-4B-nsfw-HF.IQ4_XS.gguf",
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-395391957.py in <cell line: 0>()
#       1 # !pip install llama-cpp-python
#       2
# ----> 3 from llama_cpp import Llama
#       4
#       5 llm = Llama.from_pretrained(
#
# ModuleNotFoundError: No module named 'llama_cpp'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
llm.create_chat_completion(
    messages = [
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is the capital of France?"}
    ]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2829765333.py in <cell line: 0>()
# ----> 1 llm.create_chat_completion(
#       2     messages = [
#       3         {"role": "system", "content": "You are a helpful assistant."},
#       4         {"role": "user", "content": "What is the capital of France?"}
#       5     ]
#
# NameError: name 'llm' is not defined
